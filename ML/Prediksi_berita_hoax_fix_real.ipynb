# %% [markdown]
# #Data Understanding

# %% [markdown]
# ### Import Library

# %%
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dropout, Dense
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path folder tempat menyimpan file
folder_path = "/content/drive/MyDrive/hoax_data/Cleaned"

# Daftar file non-hoax
non_hoax_files = [
    "dataset_cnn_cleaned.xlsx",
    "dataset_detik_cleaned.xlsx",
    "dataset_kompas_cleaned.xlsx"
]

# List untuk menyimpan data non-hoax
non_hoax_data = []

for file_name in non_hoax_files:
    df = pd.read_excel(os.path.join(folder_path, file_name))
    df["label"] = 0  # label non-hoax
    df["sumber"] = file_name.replace("dataset_", "").replace("_cleaned.xlsx", "")
    non_hoax_data.append(df)

# Gabungkan semua data non-hoax
df_non_hoax = pd.concat(non_hoax_data, ignore_index=True)
print("Jumlah data non-hoax:", df_non_hoax.shape)
df_non_hoax.head()
# Out:
# Jumlah data non-hoax: (12648, 9)
#                                                  url  \
# 0  https://www.cnnindonesia.com/nasional/20250420...
# 1  https://www.cnnindonesia.com/olahraga/20250420...
# 2  https://www.cnnindonesia.com/ekonomi/202504171...
# 3  https://www.cnnindonesia.com/nasional/20250420...
# 4  https://www.cnnindonesia.com/olahraga/20250420...
#
#                                                judul  \
# 0  Pesan Paskah Uskup Agung Jakarta Kardinal Igna...
# 1  Mike Tyson: Muhammad Ali Ganas seperti T-Rex, ...
# 2  Kulkas SBS Banting Harga Gila-gilaan di Transm...
# 3  Hakim Djuyamto Diduga Titip Rp704 Juta ke Satp...
# 4  Leicester vs Liverpool: Menanti Gol Kaki Kiri ...
#
#                          tanggal  \
# 0  Minggu, 20 Apr 2025 15:07 WIB
# 1  Minggu, 20 Apr 2025 15:01 WIB
# 2  Minggu, 20 Apr 2025 15:00 WIB
# 3  Minggu, 20 Apr 2025 14:44 WIB
# 4  Minggu, 20 Apr 2025 14:33 WIB
#
#                                           isi_berita  \
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...
# 2  Pesta diskon bertajukTransmart Full Day Saleke...
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...
# 4  Mohamed Salahberpeluang menciptakan rekor unik...
#
#                                               Narasi  \
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...
# 2  Pesta diskon bertajukTransmart Full Day Saleke...
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...
# 4  Mohamed Salahberpeluang menciptakan rekor unik...
#
#                                         Clean Narasi  hoax  label sumber
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...     0      0    cnn
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...     0      0    cnn
# 2  Pesta diskon bertajukTransmart Full Day Saleke...     0      0    cnn
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...     0      0    cnn
# 4  Mohamed Salahberpeluang menciptakan rekor unik...     0      0    cnn

# %%
df_hoax = pd.read_excel(os.path.join(folder_path, "dataset_turnbackhoax_cleaned.xlsx"))
df_hoax["label"] = 1  # label hoax
df_hoax["sumber"] = "turnbackhoax"

print("Jumlah data hoax:", df_hoax.shape)
df_hoax.head()
# Out:
# Jumlah data hoax: (12648, 9)
#                                                  url  \
# 0  https://turnbackhoax.id/2025/04/19/penipuan-ta...
# 1  https://turnbackhoax.id/2025/04/18/salah-video...
# 2  https://turnbackhoax.id/2025/04/17/salah-jokow...
# 3  https://turnbackhoax.id/2025/04/17/penipuan-pe...
# 4  https://turnbackhoax.id/2025/04/17/penipuan-ta...
#
#                                                judul         tanggal  \
# 0  [PENIPUAN] Tautan “New Gebyar Program Bank BCA...  April 19, 2025
# 1  [SALAH] Video “Ada Bangkai Kereta di Tebing, A...  April 18, 2025
# 2  [SALAH] Jokowi Pakai Rp38,5 Triliun Dana Haji ...  April 17, 2025
# 3          [PENIPUAN] Pencairan Dana Bansos Kemenkeu  April 17, 2025
# 4           [PENIPUAN] Tautan “Bantuan Subsidi Upah”  April 17, 2025
#
#                                           isi_berita  \
# 0  Akun Facebook “Gebyar BCA 2025” pada Rabu (26/...
# 1  Akun Facebook “Agus Jajang Nurjaman” pada Rabu...
# 2  Pada Sabtu (5/4/2025) beredarunggahandi Facebo...
# 3  Akun Facebook “bansos bantuan masyarakat” pada...
# 4  Akun Facebook “Novita Lestariarta” pada Kamis ...
#
#                                               Narasi  \
# 0  New Gebyar Program Bank BCA di TAHUN 2025 Berl...
# 1  “Bangkai gerbong kereta bekas kecelakaan mangk...
# 2  “Semoga bisa di usut tuntas #konoha” Per arsip...
# 3  “INFO BANSOS…!!! Alhamdulillah pencairan Dana ...
# 4  “AYO IBU IBU SEGERA DAFTAR KAN DIRI ANDA DI CE...
#
#                                         Clean Narasi  hoax  label  \
# 0  New Gebyar Program Bank BCA di TAHUN 2025 Berl...     1      1
# 1  Bangkai gerbong kereta bekas kecelakaan mangkr...     1      1
# 2  Semoga bisa di usut tuntas #konoha Per arsip d...     1      1
# 3  INFO BANSOS !!! Alhamdulillah pencairan Dana B...     1      1
# 4  AYO IBU IBU SEGERA DAFTAR KAN DIRI ANDA DI CEK...     1      1
#
#          sumber
# 0  turnbackhoax
# 1  turnbackhoax
# 2  turnbackhoax
# 3  turnbackhoax
# 4  turnbackhoax

# %%
# Gabungkan hoax dan non-hoax
df_all = pd.concat([df_non_hoax, df_hoax], ignore_index=True)

# Reset index dan tampilkan info
df_all = df_all.reset_index(drop=True)
print("Total data gabungan:", df_all.shape)
df_all.head()
# Out:
# Total data gabungan: (25296, 9)
#                                                  url  \
# 0  https://www.cnnindonesia.com/nasional/20250420...
# 1  https://www.cnnindonesia.com/olahraga/20250420...
# 2  https://www.cnnindonesia.com/ekonomi/202504171...
# 3  https://www.cnnindonesia.com/nasional/20250420...
# 4  https://www.cnnindonesia.com/olahraga/20250420...
#
#                                                judul  \
# 0  Pesan Paskah Uskup Agung Jakarta Kardinal Igna...
# 1  Mike Tyson: Muhammad Ali Ganas seperti T-Rex, ...
# 2  Kulkas SBS Banting Harga Gila-gilaan di Transm...
# 3  Hakim Djuyamto Diduga Titip Rp704 Juta ke Satp...
# 4  Leicester vs Liverpool: Menanti Gol Kaki Kiri ...
#
#                          tanggal  \
# 0  Minggu, 20 Apr 2025 15:07 WIB
# 1  Minggu, 20 Apr 2025 15:01 WIB
# 2  Minggu, 20 Apr 2025 15:00 WIB
# 3  Minggu, 20 Apr 2025 14:44 WIB
# 4  Minggu, 20 Apr 2025 14:33 WIB
#
#                                           isi_berita  \
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...
# 2  Pesta diskon bertajukTransmart Full Day Saleke...
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...
# 4  Mohamed Salahberpeluang menciptakan rekor unik...
#
#                                               Narasi  \
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...
# 2  Pesta diskon bertajukTransmart Full Day Saleke...
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...
# 4  Mohamed Salahberpeluang menciptakan rekor unik...
#
#                                         Clean Narasi  hoax  label sumber
# 0  Uskup Agung Jakarta Kardinal Mgr. Ignatius Suh...     0      0    cnn
# 1  Mike Tysonmenyebut legenda tinju dunia,Muhamma...     0      0    cnn
# 2  Pesta diskon bertajukTransmart Full Day Saleke...     0      0    cnn
# 3  Kejaksaan Agung (Kejagung) menyebut jumlah uan...     0      0    cnn
# 4  Mohamed Salahberpeluang menciptakan rekor unik...     0      0    cnn

# %%
# Cek jumlah baris dan kolom
print("Shape (rows, columns):", df_all.shape)

# Tipe data dan non-null count
df_all.info()
# Out:
# Shape (rows, columns): (25296, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25296 entries, 0 to 25295
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           25296 non-null  object
#  1   judul         25296 non-null  object
#  2   tanggal       25296 non-null  object
#  3   isi_berita    25292 non-null  object
#  4   Narasi        24671 non-null  object
#  5   Clean Narasi  24675 non-null  object
#  6   hoax          25296 non-null  int64
#  7   label         25296 non-null  int64
#  8   sumber        25296 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.7+ MB

# %%
df_all.nunique()
# Out:
# url             25296
# judul           25238
# tanggal         13019
# isi_berita      25290
# Narasi          24615
# Clean Narasi    24598
# hoax                2
# label               2
# sumber              4
# dtype: int64

# %%
print("Missing values per column:")
print(df_all.isnull().sum())
# Out:
# Missing values per column:
# url               0
# judul             0
# tanggal           0
# isi_berita        4
# Narasi          625
# Clean Narasi    621
# hoax              0
# label             0
# sumber            0
# dtype: int64

# %%
sns.countplot(x="label", data=df_all)
plt.title("Distribusi Label Hoax vs Non-Hoax")
plt.xticks([0, 1], ["Non-Hoax", "Hoax"])
plt.show()

# %%
# Hitung panjang karakter dari Clean Narasi
df_all["panjang_clean"] = df_all["Clean Narasi"].astype(str).apply(len)

# Histogram distribusi panjang
plt.figure(figsize=(10,5))
sns.histplot(df_all["panjang_clean"], bins=50, kde=True)
plt.title("Distribusi Panjang Teks Clean Narasi")
plt.xlabel("Jumlah Karakter")
plt.ylabel("Frekuensi")
plt.show()

# %%
df_all[df_all["Clean Narasi"].isnull() | (df_all["Clean Narasi"].astype(str).str.strip() == "")]
# Out:
#                                                      url  \
# 4409   https://news.detik.com/kolom/d-7874698/pengala...
# 5168   https://news.detik.com/kolom/d-7868362/membaca...
# 13559  https://turnbackhoax.id/2024/10/02/penipuan-lo...
# 13759  https://turnbackhoax.id/2024/09/24/penipuan-to...
# 13910  https://turnbackhoax.id/2024/09/10/salah-pm-si...
# ...                                                  ...
# 25248  https://turnbackhoax.id/2020/01/09/false-dange...
# 25254  https://turnbackhoax.id/2020/01/08/false-dog-s...
# 25263  https://turnbackhoax.id/2020/01/07/clarificati...
# 25278  https://turnbackhoax.id/2020/01/03/salah-judul...
# 25295  https://turnbackhoax.id/2020/01/01/false-niger...
#
#                                                    judul  \
# 4409   Pengalaman Cek Kesehatan Gratis Hadiah Ultah P...
# 5168   Membaca Pertemuan Prabowo-Megawati Jelang Kong...
# 13559  [PENIPUAN] Lowongan Perawat RSUD Jombang Tahun...
# 13759  [PENIPUAN] Tommy Winata, Pemilik PT Artha Grah...
# 13910  [SALAH] PM Singapura Sebut: Negara Gila Agama,...
# ...                                                  ...
# 25248           [FALSE] “dangerous Snack made in Israel”
# 25254      [FALSE] “dog saved infant koala in the fires”
# 25263  [CLARIFICATION] Photos of “Sam the Koala” and ...
# 25278  [SALAH] Judul berita Tempo “MUI minta agar jan...
# 25295           [FALSE] “Nigerian boys roasted to death”
#
#                              tanggal  \
# 4409    Sabtu, 19 Apr 2025 11:05 WIB
# 5168   Selasa, 15 Apr 2025 10:48 WIB
# 13559                October 2, 2024
# 13759             September 24, 2024
# 13910             September 10, 2024
# ...                              ...
# 25248                January 9, 2020
# 25254                January 8, 2020
# 25263                January 7, 2020
# 25278                January 3, 2020
# 25295                January 1, 2020
#
#                                               isi_berita Narasi Clean Narasi  \
# 4409                             [Gambas:Video 20detik]     NaN          NaN
# 5168                             [Gambas:Video 20detik]     NaN          NaN
# 13559  Hasil periksa fakta Arief Putra Ramadhan. RSUD...    NaN          NaN
# 13759  Hasil periksa fakta Arief Putra Ramadhan. Vide...    NaN          NaN
# 13910  Artikel hasil periksa fakta Vinanda (Relawan M...    NaN          NaN
# ...                                                  ...    ...          ...
# 25248  Recycled disinformation, product of Turkey NOT...    NaN          NaN
# 25254  From freezing, NOT from the fire. Happened in ...    NaN          NaN
# 25263  Both image are related to Australia’s 2009 “Bl...    NaN          NaN
# 25278  Gambar suntingan.Tempo.cotidak pernah memuat b...    NaN          NaN
# 25295  NOT a real person. The image is from a diorama...    NaN          NaN
#
#        hoax  label        sumber  panjang_clean
# 4409      0      0         detik              3
# 5168      0      0         detik              3
# 13559     1      1  turnbackhoax              3
# 13759     1      1  turnbackhoax              3
# 13910     1      1  turnbackhoax              3
# ...     ...    ...           ...            ...
# 25248     1      1  turnbackhoax              3
# 25254     1      1  turnbackhoax              3
# 25263     1      1  turnbackhoax              3
# 25278     1      1  turnbackhoax              3
# 25295     1      1  turnbackhoax              3
#
# [621 rows x 10 columns]

# %% [markdown]
# #Data Preparation

# %%
# Hapus data kosong atau kosong string di Clean Narasi
df_model = df_all[["Clean Narasi", "label"]].dropna()
df_model = df_model[df_model["Clean Narasi"].str.strip() != ""]
df_model = df_model.reset_index(drop=True)

print("Data setelah dibersihkan:", df_model.shape)
# Out:
# Data setelah dibersihkan: (24675, 2)

# %%
sns.countplot(x="label", data=df_model)
plt.xticks([0,1], ["Non-Hoax", "Hoax"])
plt.title("Distribusi Label")
plt.show()

# %%
# Tokenizer
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(df_model["Clean Narasi"])

# Konversi ke sequence dan padding
sequences = tokenizer.texts_to_sequences(df_model["Clean Narasi"])
maxlen = 200
X = pad_sequences(sequences, maxlen=maxlen, padding='post', truncating='post')
y = df_model["label"].values

print("Contoh padding:\n", X[0][:20])
# Out:
# Contoh padding:
#  [4672  468   20 6193 7371 9012 3828    1    1  483    6  408 3715    4
#   389  475   74    2 3971    4]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print("Train shape:", X_train.shape)
print("Test shape :", X_test.shape)
# Out:
# Train shape: (19740, 200)
# Test shape : (4935, 200)

# %% [markdown]
# # Modeling and Result

# %%
# Parameter
vocab_size = 10000
embedding_dim = 64
input_length = X_train.shape[1]

# Arsitektur model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=input_length),
    GlobalAveragePooling1D(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Bangun model secara eksplisit (agar summary tampil lengkap)
model.build(input_shape=(None, input_length))
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_12 (Embedding)        │ (None, 200, 64)        │       640,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_12     │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 642,113 (2.45 MB)
#  Trainable params: 642,113 (2.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
SEED = 42

# Set seed untuk Python, NumPy, TensorFlow
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Gunakan CPU saja untuk hasil yang deterministik
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# Saat .fit(), tambahkan shuffle=False
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test),
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.8336 - loss: 0.3782 - val_accuracy: 0.9763 - val_loss: 0.0781
# Epoch 2/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9800 - loss: 0.0644 - val_accuracy: 0.9893 - val_loss: 0.0451
# Epoch 3/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9905 - loss: 0.0342 - val_accuracy: 0.9899 - val_loss: 0.0401
# Epoch 4/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9932 - loss: 0.0257 - val_accuracy: 0.9899 - val_loss: 0.0389
# Epoch 5/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9948 - loss: 0.0209 - val_accuracy: 0.9893 - val_loss: 0.0398
# Epoch 6/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9966 - loss: 0.0153 - val_accuracy: 0.9897 - val_loss: 0.0419
# Epoch 7/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9967 - loss: 0.0131 - val_accuracy: 0.9895 - val_loss: 0.0442
# Epoch 8/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9969 - loss: 0.0139 - val_accuracy: 0.9907 - val_loss: 0.0412
# Epoch 9/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9979 - loss: 0.0084 - val_accuracy: 0.9889 - val_loss: 0.0503
# Epoch 10/10
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9973 - loss: 0.0099 - val_accuracy: 0.9903 - val_loss: 0.0461

# %%
# Akurasi
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9895 - loss: 0.0422
# Test Accuracy: 0.9903

# %% [markdown]
# # Evaluation

# %%
# Prediksi
y_pred = (model.predict(X_test) > 0.5).astype(int)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Non-Hoax", "Hoax"], yticklabels=["Non-Hoax", "Hoax"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Classification report
print(classification_report(y_test, y_pred, target_names=["Non-Hoax", "Hoax"]))
# Out:
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#     Non-Hoax       0.99      1.00      0.99      2529
#         Hoax       1.00      0.98      0.99      2406
#
#     accuracy                           0.99      4935
#    macro avg       0.99      0.99      0.99      4935
# weighted avg       0.99      0.99      0.99      4935

# %%
def prediksi_berita(narasi_baru):
    # Preprocessing: ubah ke bentuk list agar bisa diproses tokenizer
    narasi_seq = tokenizer.texts_to_sequences([narasi_baru])
    narasi_pad = pad_sequences(narasi_seq, maxlen=maxlen, padding='post', truncating='post')

    # Prediksi
    prob = model.predict(narasi_pad)[0][0]
    label = 1 if prob >= 0.5 else 0
    status = "HOAX" if label == 1 else "BUKAN HOAX"

    print(f"Prediksi: {status}")
    print(f"Probabilitas Hoax: {prob:.4f}")

# %%
berita_uji = """
ijazah jokowi adalah ijazah palsu
"""

prediksi_berita(berita_uji)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Prediksi: HOAX
# Probabilitas Hoax: 0.9993

# %%
model.save("model_hoax_fix.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load model dari file h5
model = load_model("model_hoax.h5")
def prediksi_berita(narasi_baru):
    # Preprocessing sama seperti sebelumnya
    narasi_seq = tokenizer.texts_to_sequences([narasi_baru])
    narasi_pad = pad_sequences(narasi_seq, maxlen=200, padding='post', truncating='post')

    # Prediksi
    prob = model.predict(narasi_pad)[0][0]
    label = 1 if prob >= 0.5 else 0
    status = "HOAX" if label == 1 else "BUKAN HOAX"

    print(f"Narasi: {narasi_baru.strip()[:100]}...")
    print(f"Prediksi: {status}")
    print(f"Probabilitas Hoax: {prob:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
contoh_narasi = """
pemerintah indonesia terus berupaya meningkatkan pelayanan kesehatan bagi seluruh masyarakat melalui program jaminan kesehatan nasional yang dikelola bpjs kesehatan masyarakat kini dapat memperoleh akses layanan kesehatan dengan lebih mudah sejak diluncurkan program ini telah membantu jutaan warga mendapatkan perawatan medis tanpa harus mengkhawatirkan biaya selama pandemi covid19 bpjs tetap aktif melayani pasien dan mendukung pemerintah dalam pembiayaan pengobatan covid19 informasi mengenai penghentian program bpjs karena kebangkrutan adalah tidak benar pemerintah terus mengalokasikan dana dan memperkuat sistem agar program jkn tetap berkelanjutan dan menjangkau seluruh penduduk indonesia selalu pastikan mendapatkan informasi dari sumber resmi agar tidak mudah termakan isu yang menyesatkan
"""

prediksi_berita(contoh_narasi)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Narasi: pemerintah indonesia terus berupaya meningkatkan pelayanan kesehatan bagi seluruh masyarakat melalui...
# Prediksi: BUKAN HOAX
# Probabilitas Hoax: 0.3160
